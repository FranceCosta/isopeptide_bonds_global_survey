# %%
import pandas as pd

# %%
df = pd.read_csv("output/20250115_vbdf_scan.csv")
df
# Out:
#                                            struct_file uniprot_acc  \
# 0    /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A6J5P0L4
# 1    /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A481Z682
# 2    /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A1V0SA58
# 3    /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A2I7QL19
# 4    /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A8S5VG59
# ..                                                 ...         ...
# 452  /hps/nobackup/agb/interpro/mblum/bfvd/structur...      K7YAT7
# 453  /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A1V0SFF3
# 454  /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A858NPN3
# 455  /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A1J0FA25
# 456  /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A345BLR6
#
#      probability chain  r1_bond  r_cat  r2_bond r1_bond_name r_cat_name  \
# 0          0.095     A      252     96      107          LYS        ASP
# ...

# %%
df[df["probability"]>.65].drop_duplicates("uniprot_acc")
# Out:
#                                            struct_file uniprot_acc  \
# 48   /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A8S5U8F9
# 50   /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A7G3MPL8
# 52   /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A6N1NXY1
# 303  /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A8S5VTA4
# 304  /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A1V0SH75
# 305  /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A1B0YTK1
# 311  /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A3G4ZRG9
# 312  /hps/nobackup/agb/interpro/mblum/bfvd/structur...  A0A481ZEL4
#
#      probability chain  r1_bond  r_cat  r2_bond r1_bond_name r_cat_name  \
# 48         0.961     A      175    205      279          LYS        ASP
# 50         0.908     A      151    206      240          LYS        GLU
# 52         0.911     A      420    454      508          LYS        ASP
# 303        0.831     A      496    553      636          LYS        ASP
# ...
