# %% [markdown]
# # Analyse Isopeptor's scan on the AFDB

# %%
import pandas as pd
import os
import glob
import seaborn as sns 
import re
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import matplotlib as mpl
from dotenv import load_dotenv
load_dotenv("../.env")
pd.set_option('display.max_columns', None)

# %%
AFDB_JESS_SCAN_TABLE = os.getenv("AFDB_JESS_SCAN_TABLE")
AFDB_DOMAINS= os.getenv("AFDB_DOMAINS")
AFDB_SCAN_SEQS = os.getenv("AFDB_SCAN_SEQS")
FA_PRED = os.getenv("FA_PRED")
ADH_TABLE = os.getenv("ADH_TABLE")
STALK_TABLE = os.getenv("STALK_TABLE")
PATHOGENS = os.getenv("PATHOGENS")
PDB_BIOCHEM = os.getenv("PDB_BIOCHEM")

str_df = pd.read_csv(AFDB_JESS_SCAN_TABLE)
strd_df = pd.read_csv(AFDB_DOMAINS)
str_df["mean_plddt"] = str_df[["r1_plddt", "r2_plddt", "r3_plddt"]].mean(axis=1)

seq_df = pd.read_csv(AFDB_SCAN_SEQS)
seq_df["seq_len"] = seq_df["sequence"].apply(len)

pdb_df = pd.read_csv(PDB_BIOCHEM)

# %%
non_isopep = [
    "Helicase_C_2",
    'DUF7617',
    'Cu-oxidase_2',
    'DeoC',
    'Ion_trans',
    'AsmA',
    'Radical_SAM',
    'CarboxypepD_reg',
    'Ribonuc_L-PSP',
    'Phosphorylase',
    'Ufd2P_core',
    'DUF2334',
    'HEM4',
    'Transpeptidase',
    'Arginosuc_syn_C',
    'Arabinose_Iso_C',
    'Glyco_hydro_79n',
    'Peptidase_C13',
    'Phage_portal_2',
    'MbnP',
    'AsnA',
    'GH113',
    'TruD',
    'GCE_fung',
    'ATG22',
    'DrsE_2',
    'Glyco_hydro_38C',
    'Glyco_hydro_3',
    'ELFV_dehydrog',
    'MFS_1',
    'MFS_2',
    'Lip_A_acyltrans',
    'HTH_24',
    'N6_Mtase',
    'NB-ARC',
    'NUDIX',
    'NUP214',
    'DUF4203',
    'DUF5723',
    'Memo',
    'MucBP',
    'Nrap_D2',
    'NYN',
    'PBP_dimer_2',
    'Omp85',
    'PI3_PI4_kinase',
    'Cu-oxidase_4',
    'DDE_Tnp_1',
    'DUF1397',
    'Ribosomal_S3Ae',
    'RnaseA',
    'SBP_bac_1',
    'SBP_bac_8',
    'SRR1',
    'Usher',
    'WD40',
    'YycH'
]

isopep = [
    'SdrD_B',
    'SpaA',
    'DUF11',
    'Cna_B',
    'DUF7507',
    'Collagen_bind',
    'FctA',
    'GramPos_pilinBB',
    'DUF5979',
    'GramPos_pilinD1',
    'DUF7619',
    'AgI_II_C2',
    'SpaA_4',
    'Helicase_C_2',
    'DUF7933',
    'Antigen_C',
    'SpaA_2',
    'GBS104-like_Ig',
    'DUF7927',
    'SpaA_3',
    'Sgo0707_N2',
    'DUF7926',
    'GramPos_pilinD3',
    'DUF7617',
    'DUF7929',
    'DUF7925',
    'DUF7601', 'CARDB' # These ones not present in the paper (to Few hits)
]

# %%
# Find sortase motifs

S = re.compile('LP.T[G|A|N|D]')
S2 = re.compile('NP.TG')
S3 = re.compile('LP.GA')
S4 = re.compile('LA.TG')
S5 = re.compile('NPQTN')
S6 = re.compile('IP.TG')

def find_sortase(seq:str):
    """
    
        Find sortase motifs within 50 amino acids from C-ter
    
    """
    sortase = False
    seq = seq[-50:]
    if S.findall(seq):
        sortase = True
    elif S2.findall(seq):
        sortase = True
    elif S3.findall(seq):
        sortase = True
    elif S4.findall(seq):
        sortase = True
    elif S5.findall(seq):
        sortase = True
    elif S6.findall(seq):
        sortase = True
    
    return sortase

ib_proteins = str_df[(str_df["probability"]>.65)&(str_df["kingdom"]=="Bacteria")&(~str_df["pfamA_id"].isin(non_isopep))]["uniprot_acc"].unique()
sub_df = seq_df[(seq_df["uniprot_acc"].isin(ib_proteins))].copy()
sub_df["Sortase motif"] = sub_df["sequence"].apply(find_sortase)

# Add to domains database
strd_df = pd.concat([strd_df, sub_df[(sub_df["Sortase motif"])][["uniprot_acc"]]\
        .assign(pfamA_id="Sortase motif")\
        .assign(pfamA_acc="PFXXXXX")[["uniprot_acc", "pfamA_acc", "pfamA_id"]]])

# %% [markdown]
# ## General plots

# %%
TABLE = os.getenv("TABLE")

tmp_df = pd.read_csv(TABLE)

# %%
# Plot now 

plot_df = df[(df["probability"]>.65)&(~df["taxonomy"].isna())].copy()
plot_df["pfamA_id"] = plot_df["pfamA_id"].fillna("Not annotated")
plot_df["pfamA_id"] = plot_df["pfamA_id"].replace({"DUF11":"CLIPPER", "DUF7507":"CLIPPER_2"})
plot_df = plot_df.value_counts(["kingdom", "pfamA_id"]).reset_index()\
                 .query('count>=20&kingdom!="unclassified sequences"')\
                 .pivot(index="pfamA_id", columns="kingdom", values="count").fillna(0).astype(int)\
                 [["Bacteria", "Archaea", "Eukaryota"]]\
                 .sort_values(["Bacteria", "Archaea", "Eukaryota"], ascending=[False, False, False]).T\
                 .fillna(0)

false_positive_ids = ["Cu-oxidase_2", "DeoC", "TRAP_beta", "Ion_trans", "CarboxypepD_reg", "Helicase_C_2"]

# Create masks for false positives and non-false positives (columns-based)
false_positive_mask = plot_df.columns.isin(false_positive_ids)

# Separate data into two layers: false positives and non-false positives
false_positives_layer = plot_df.astype(float).copy()
false_positives_layer.loc[:, ~false_positive_mask] = np.nan  # Keep only false positives

non_false_positives_layer = plot_df.astype(float).copy()
non_false_positives_layer.loc[:, false_positive_mask] = np.nan  # Exclude false positives

# Create colormaps with custom "under" or "over" values
cmap_false_positives = plt.get_cmap("Reds").copy()
cmap_false_positives.set_under("none")  # Make non-values invisible

cmap_non_false_positives = plt.get_cmap("Blues").copy()
cmap_non_false_positives.set_under("none")  # Make non-values invisible

fig, ax = plt.subplots(figsize=[10,5])

sns.heatmap(non_false_positives_layer, cmap=cmap_non_false_positives, 
            ax=ax, annot=True, annot_kws={'fontsize': 6}, fmt=",.0f", cbar=False)

sns.heatmap(false_positives_layer, cmap=cmap_false_positives, 
            ax=ax, annot=True, annot_kws={'fontsize': 6}, fmt=",.0f", cbar=False)

ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
ax.set_aspect(0.9)
ax.set_title("Predicted intramolecular isopeptide bonds", fontsize=15, pad=20)
ax.set_ylabel("")
ax.set_xlabel("Pfam domain id")

# Add countour lines
for _, spine in ax.spines.items():
    spine.set_visible(True)

#plt.savefig("../tmp/domain_res_fp.png", dpi=400, transparent=True, bbox_inches="tight")

# %%
plot_df = df[(df["probability"]>.65)&(df["kingdom"].isin(["Bacteria", "Archaea"]))].copy()
plot_df["pfamA_id"] = plot_df["pfamA_id"].fillna("Not annotated")
plot_df["pfamA_id"] = plot_df["pfamA_id"].replace({"DUF11":"CLIPPER", "DUF7507":"CLIPPER_2"})
plot_df = plot_df.value_counts(["kingdom", "pfamA_id"]).reset_index()\
                 .query('count>=20')\
                 .pivot(index="pfamA_id", columns="kingdom", values="count").fillna(0).astype(int)\
                 [["Bacteria", "Archaea"]]\
                 .sort_values(["Bacteria", "Archaea"], ascending=[False, False]).T\
                 .fillna(0)

known_domains = ['DUF5979', 'AgI_II_C2', 'SpaA', 'Sgo0707_N2', 'GramPos_pilinBB',
       'GramPos_pilinD3', 'Collagen_bind', 'FctA', 'GramPos_pilinD1',
       'Antigen_C', 'GBS104-like_Ig', 'Cna_B']

# Create masks for known domains and non-false positives (columns-based)
known_domains_mask = plot_df.columns.isin(known_domains)

# Separate data into two layers: false positives and non-false positives
false_positives_layer = plot_df.astype(float).copy()
false_positives_layer.loc[:, ~known_domains_mask] = np.nan  # Keep only false positives

non_false_positives_layer = plot_df.astype(float).copy()
non_false_positives_layer.loc[:, known_domains_mask] = np.nan  # Exclude false positives

# Create colormaps with custom "under" or "over" values
cmap_false_positives = plt.get_cmap("Blues").copy()
cmap_false_positives.set_under("none")  # Make non-values invisible

cmap_non_false_positives = plt.get_cmap("Oranges").copy()
cmap_non_false_positives.set_under("none")  # Make non-values invisible

fig, ax = plt.subplots(figsize=[10,5])

sns.heatmap(non_false_positives_layer, cmap=cmap_non_false_positives, 
            ax=ax, annot=True, annot_kws={'fontsize': 6}, fmt=",.0f", cbar=False)

sns.heatmap(false_positives_layer, cmap="Grays", vmin=1, vmax=1,
            ax=ax, annot=True, annot_kws={'fontsize': 6}, fmt=",.0f", cbar=False)

ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
ax.set_aspect(0.9)
ax.set_title("Predicted intramolecular isopeptide bonds", fontsize=15, pad=20)
ax.set_ylabel("")
ax.set_xlabel("Pfam domain id")

# Add countour lines
for _, spine in ax.spines.items():
    spine.set_visible(True)

plt.savefig("../tmp/domain_res_known.png", dpi=400, transparent=True, bbox_inches="tight")

# %%
sns.histplot(data=df, x="rmsd")
# Out:
# <Axes: xlabel='rmsd', ylabel='Count'>

# %%
sns.histplot(data=df, x="probability")
plt.ylim([0,1000])
# Out:
# (0.0, 1000.0)

# %%
# probability vs plddt
plot_df = df[~df["taxonomy"].isna()].copy()
plot_df["Predicted with intramolecular isopeptide bond"] = False
plot_df.loc[plot_df["probability"]>.65, "Predicted with intramolecular isopeptide bond"] = True
sns.histplot(data=plot_df, x="mean_plddt", bins=10, binrange=[0,100], 
             hue="Predicted with intramolecular isopeptide bond", multiple="dodge")
# Out:
# <Axes: xlabel='mean_plddt', ylabel='Count'>

# %%
kingdom = "Bacteria"

ib_domains = str_df[(str_df["probability"]>.65)&(str_df["kingdom"].isin([kingdom]))&(~str_df["pfamA_id"].isin(non_isopep))]["pfamA_acc"].unique()
# Consider only proteins with isopep bonds
ib_proteins = str_df[(str_df["probability"]>.65)&(str_df["kingdom"].isin([kingdom]))&(~str_df["pfamA_id"].isin(non_isopep))]["uniprot_acc"].unique()

strd_df[(strd_df["uniprot_acc"].isin(ib_proteins))&(~strd_df["pfamA_acc"].isin(ib_domains))].value_counts("pfamA_id").iloc[:50]
# Out:
# pfamA_id
# Gram_pos_anchor    4668
# Big_8              2392
# TQ                 2242
# Por_Secre_tail      932
# TED                 914
# VWA                 655
# CHU_C               653
# Big_9               621
# VWA_2               425
# pAdhesive_15        420
# TED_2               291
# Bact_lectin         285
# QPE                 236
# GEVED               235
# Adhesin_P1_N        228
# Calx-beta           202
# DUF6923             200
# Flg_new             197
# FG-GAP_3            193
# SLH                 156
# CshA_NR2            152
# Ig_7                150
# SprB                145
# DUF5122             138
# TSP3_bac            129
# HemolysinCabind     125
# RCC1                123
# IPTL-CTERM          119
# SHIRT               113
# SBBP                111
# Fn_bind             110
# CshA_repeat         109
# WxL                 106
# Ice_binding         106
# PKD_4               100
# Flg_new_2            94
# Beta_helix           79
# GbpC                 76
# P_proprotein         75
# Strep_SA_rep         73
# LTD                  66
# DUF285               65
# Peptidase_S8         65
# BspA_v               64
# DUF4183              63
# IgGFc_binding        61
# Sortase              59
# YSIRK_signal         56
# FG-GAP_2             56
# PA                   53
# Name: count, dtype: int64

# %%
kingdom = "Archaea"

#ib_domains = str_df[(str_df["probability"]>.65)&(str_df["kingdom"].isin([kingdom]))&(~str_df["pfamA_id"].isin(non_isopep))]["pfamA_acc"].unique()
# Consider only proteins with isopep bonds
ib_proteins = str_df[(str_df["probability"]>.65)&(str_df["kingdom"].isin([kingdom]))&(~str_df["pfamA_id"].isin(non_isopep))]["uniprot_acc"].unique()


print(len(strd_df[(strd_df["uniprot_acc"].isin(ib_proteins))].drop_duplicates("uniprot_acc")))
strd_df[(strd_df["uniprot_acc"].isin(ib_proteins))].value_counts("pfamA_id").iloc[:20]
# Out:
# 675
# pfamA_id
# DUF11              1332
# SdrD_B               93
# Chlam_PMP            52
# HemolysinCabind      43
# PKD_4                37
# Cna_B                36
# SpaA_2               26
# Beta_helix           25
# DUF4215              17
# Big_7                17
# SpaA                 16
# PGF-CTERM            15
# PKD                  15
# CarboxypepD_reg      15
# Cu-binding_MopE      14
# NosD                 13
# Big_9                13
# BACON_2              13
# PQQ                  12
# CARDB                12
# Name: count, dtype: int64

# %%
# How many proteins do not associate with any other domain?


kingdom = "Archaea"

ib_domains = str_df[(str_df["probability"]>.65)&(~str_df["pfamA_id"].isin(non_isopep))]["pfamA_acc"].unique()
# Consider only proteins with isopep bonds
ib_proteins = str_df[(str_df["probability"]>.65)&(str_df["kingdom"].isin([kingdom]))&(~str_df["pfamA_id"].isin(non_isopep))]["uniprot_acc"].unique()

ib_proteins_with_other_domains = strd_df[(strd_df["uniprot_acc"].isin(ib_proteins))&(~strd_df["pfamA_acc"].isin(ib_domains))]["uniprot_acc"].unique()
print(len(strd_df[(strd_df["uniprot_acc"].isin(ib_proteins))&(~strd_df["uniprot_acc"].isin(ib_proteins_with_other_domains))].drop_duplicates("uniprot_acc")))

strd_df[(strd_df["uniprot_acc"].isin(ib_proteins))&(~strd_df["uniprot_acc"].isin(ib_proteins_with_other_domains))].drop_duplicates("uniprot_acc").iloc[20:40]
# Out:
# 463
#        uniprot_acc pfamA_acc pfamA_id clan_acc clan_id  seq_start  seq_end
# 188218  A0A2I0NW27   PF01345    DUF11   CL0159   E-set       34.0    146.0
# 188298  A0A1G5XMQ2   PF01345    DUF11   CL0159   E-set       71.0    185.0
# 188315  A0A3G9D216   PF01345    DUF11   CL0159   E-set        1.0    110.0
# 188318  A0A832LKW6   PF01345    DUF11   CL0159   E-set        1.0    110.0
# 188338  A0A843F7D5   PF01345    DUF11   CL0159   E-set      313.0    425.0
# 188346  A0A368TE33   PF01345    DUF11   CL0159   E-set      187.0    303.0
# 188414  A0A842KTB3   PF01345    DUF11   CL0159   E-set      365.0    480.0
# 188417  A0A842L8J2   PF01345    DUF11   CL0159   E-set      365.0    480.0
# 188465  A0A843IV74   PF01345    DUF11   CL0159   E-set      213.0    326.0
# 188498  A0A843F8U5   PF01345    DUF11   CL0159   E-set        1.0     98.0
# 188503  A0A2I0NVV0   PF01345    DUF11   CL0159   E-set        1.0     93.0
# 188802  A0A328P8W5   PF01345    DUF11   CL0159   E-set        1.0     74.0
# 188991      K2R5M7   PF01345    DUF11   CL0159   E-set      261.0    384.0
# 189021  A0A2I0PIZ3   PF01345    DUF11   CL0159   E-set       83.0    199.0
# 189059      U6EEA5   PF01345    DUF11   CL0159   E-set       76.0    203.0
# 189084  A0A843G960   PF01345    DUF11   CL0159   E-set      309.0    422.0
# 189155  A0A090I5G5   PF01345    DUF11   CL0159   E-set       44.0    161.0
# 189209  A0A166CST7   PF01345    DUF11   CL0159   E-set      583.0    697.0
# 189246  A0A7J4MW61   PF01345    DUF11   CL0159   E-set        1.0     72.0
# 189271  A0A7J3TLV7   PF01345    DUF11   CL0159   E-set      107.0    203.0

# %%
prots = strd_df[(strd_df["uniprot_acc"].isin(ib_proteins))&(strd_df["pfamA_id"].isin(["Chlam_PMP"]))]["uniprot_acc"].unique()
str_df[str_df["uniprot_acc"].isin(prots)]["taxonomy"].iloc[0]
# Out:
# 'Archaea; Euryarchaeota; Methanomada group; Methanobacteria; Methanobacteriales; Methanobacteriaceae; Methanobrevibacter.'

# %%
# Get all IB-domain to any other domain association

# ATTENTION: the algorithm is wrong and over-estimating the number of co-localizations

str_df = df.copy()
kingdom = "Bacteria"

isopep = ['Collagen_bind', 'GramPos_pilinBB', 'AgI_II_C2', 'Antigen_C',
       'Sgo0707_N2', 'DUF11', 'DUF7507', 'DUF7619', 'GBS104-like_Ig',
       'DUF7617', 'CARDB', 'SpaA', 'Cna_B', 'FctA', 'DUF5979',
       'GramPos_pilinD1', 'DUF7601', 'SpaA_4', 'SpaA_2', 'SpaA_3',
       'GramPos_pilinD3', 'SdrD_B', 'Not annotated']

# Consider only proteins with isopep bonds
ib_proteins = str_df[(str_df["probability"]>.65)&(str_df["kingdom"].isin([kingdom]))&(~str_df["pfamA_id"].isin(non_isopep))]["uniprot_acc"].unique()
# Concat to include domains added via hmm scan;
# Then drop duplicates to remove duplicated entries with no probability
table_df = pd.concat([
    strd_df[(strd_df["uniprot_acc"].isin(ib_proteins))] \
    .assign(probability=0)[["uniprot_acc", "pfamA_acc", "pfamA_id", "seq_start", "seq_end"]], 
        str_df[(str_df["probability"]>.65) & \
        (str_df["kingdom"].isin([kingdom])) & \
        (~str_df["pfamA_id"].isin(non_isopep))][["uniprot_acc", "pfamA_acc", "pfamA_id", "seq_start", "seq_end", "probability"]]
                     ]).sort_values("probability", ascending=False).drop_duplicates(keep="first")
table_df["probability"] = table_df["probability"].fillna(0)
table_df = table_df.fillna("Not annotated")
# Sort to have ib first
table_df = table_df.sort_values(["uniprot_acc", "probability"], ascending=[True, False])
all_domains = table_df["pfamA_id"].unique()

# Store ibd-non-ibds association information
paired_data = {ibd:{d:0 for d in all_domains} for ibd in isopep}
uniprot_acc = ""
ibds = []
non_ibds = []
for index, row in table_df.iterrows():
    tmp_uniprot_acc = row["uniprot_acc"]
    if tmp_uniprot_acc != uniprot_acc:
        for ibd in ibds:
            for non_ibd in non_ibds:
                # Skip self-self associations
                if ibd == non_ibd:
                    continue
                paired_data[ibd][non_ibd] += 1
        # Reset for next protein
        ibds = []
        non_ibds = []
        uniprot_acc = tmp_uniprot_acc
    pfamA_id = row["pfamA_id"]
    probability = row["probability"]
    # Add to ibd only if part of isopep and with prob >.65
    if probability > 0.65:
        if pfamA_id not in isopep:
            continue
        ibds.append(pfamA_id)
    else:
        non_ibds.append(pfamA_id)

# Minimal count of domain associations criteria for plotting
min_count = 50
plot_df = pd.DataFrame(paired_data).T
# Non ipb domains to inlcude based on minimal count
to_include = pd.DataFrame(plot_df.sum(axis=0), columns=["count"]).query(f'count>{min_count}').index
# Exclude ibds
to_include = [d for d in to_include if d not in isopep]
plot_df = plot_df[to_include].rename(index={"DUF11":"CLIPPER", "DUF7507":"CLIPPER_2"})

fig, ax = plt.subplots(figsize=[30,10])

# Note that self-self associations are not considered
sns.heatmap(plot_df, ax=ax, cbar=False, cmap="Blues", annot=True, annot_kws={'fontsize': 12}, fmt=",.0f")

ax.set_ylabel("Intramolecular isopeptide bond - containing domains")
ax.set_xlabel("Non intramolecular isopeptide bond - containing domains")
# Out:
# Text(0.5, 80.5815972222222, 'Non intramolecular isopeptide bond - containing domains')

# %%
duf11_proteins = str_df[(str_df["probability"]>.65)&(str_df["pfamA_id"]=="DUF11")&(str_df["kingdom"]=="Bacteria")]["uniprot_acc"].unique()
table_df[table_df["uniprot_acc"].isin(duf11_proteins) & (table_df["pfamA_id"]=="Cadherin_4")]
# Out:
#        uniprot_acc pfamA_acc    pfamA_id seq_start seq_end  probability
# 987443  A0A016QLQ3   PF17803  Cadherin_4     428.0   508.0          0.0
# 987405  A0A090PM07   PF17803  Cadherin_4     575.0   643.0          0.0
# 987423  A0A090PZQ0   PF17803  Cadherin_4      99.0   167.0          0.0
# 987452  A0A090QG10   PF17803  Cadherin_4     473.0   542.0          0.0
# 987259  A0A090VFK5   PF17803  Cadherin_4      87.0   161.0          0.0
# ...            ...       ...         ...       ...     ...          ...
# 987406      A5CM85   PF17803  Cadherin_4     898.0   974.0          0.0
# 987351      B0RBI0   PF17803  Cadherin_4     895.0   964.0          0.0
# 987195      H8KXH1   PF17803  Cadherin_4      62.0   129.0          0.0
# 987196      H8KXH1   PF17803  Cadherin_4     155.0   228.0          0.0
# 987197      H8KXH1   PF17803  Cadherin_4     254.0   324.0          0.0
#
# [157 rows x 6 columns]

# %%
# Get all IB-domain to any other domain association

str_df = df.copy()
kingdom = "Archaea"

isopep = ['Collagen_bind', 'GramPos_pilinBB', 'AgI_II_C2', 'Antigen_C',
       'Sgo0707_N2', 'DUF11', 'DUF7507', 'DUF7619', 'GBS104-like_Ig',
       'DUF7617', 'CARDB', 'SpaA', 'Cna_B', 'FctA', 'DUF5979',
       'GramPos_pilinD1', 'DUF7601', 'SpaA_4', 'SpaA_2', 'SpaA_3',
       'GramPos_pilinD3', 'SdrD_B', 'Not annotated']

# Consider only proteins with isopep bonds
ib_proteins = str_df[(str_df["probability"]>.65)&(str_df["kingdom"].isin([kingdom]))&(~str_df["pfamA_id"].isin(non_isopep))]["uniprot_acc"].unique()
# Concat to include domains added via hmm scan;
# Then drop duplicates to remove duplicated entries with no probability
table_df = pd.concat([
    strd_df[(strd_df["uniprot_acc"].isin(ib_proteins))] \
    .assign(probability=0)[["uniprot_acc", "pfamA_acc", "pfamA_id", "seq_start", "seq_end"]], 
        str_df[(str_df["probability"]>.65) & \
        (str_df["kingdom"].isin([kingdom])) & \
        (~str_df["pfamA_id"].isin(non_isopep))][["uniprot_acc", "pfamA_acc", "pfamA_id", "seq_start", "seq_end", "probability"]]
                     ]).sort_values("probability", ascending=False).drop_duplicates(keep="first")
table_df["probability"] = table_df["probability"].fillna(0)
table_df = table_df.fillna("Not annotated")
# Sort to have ib first
table_df = table_df.sort_values(["uniprot_acc", "probability"], ascending=[True, False])
all_domains = table_df["pfamA_id"].unique()

# Store ibd-non-ibds association information
paired_data = {ibd:{d:0 for d in all_domains} for ibd in isopep}
uniprot_acc = ""
ibds = []
non_ibds = []
for index, row in table_df.iterrows():
    tmp_uniprot_acc = row["uniprot_acc"]
    if tmp_uniprot_acc != uniprot_acc:
        for ibd in ibds:
            for non_ibd in non_ibds:
                # Skip self-self associations
                if ibd == non_ibd:
                    continue
                paired_data[ibd][non_ibd] += 1
        # Reset for next protein
        ibds = []
        non_ibds = []
        uniprot_acc = tmp_uniprot_acc
    pfamA_id = row["pfamA_id"]
    probability = row["probability"]
    # Add to ibd only if part of isopep and with prob >.65
    if probability > 0.65:
        if pfamA_id not in isopep:
            continue
        ibds.append(pfamA_id)
    else:
        non_ibds.append(pfamA_id)

# Minimal count of domain associations criteria for plotting
min_count = 50
plot_df = pd.DataFrame(paired_data).T
# Non ipb domains to inlcude based on minimal count
to_include = pd.DataFrame(plot_df.sum(axis=0), columns=["count"]).query(f'count>{min_count}').index
# Exclude ibds
to_include = [d for d in to_include if d not in isopep]
plot_df = plot_df[to_include].rename(index={"DUF11":"CLIPPER", "DUF7507":"CLIPPER_2"})

fig, ax = plt.subplots(figsize=[30,10])

# Note that self-self associations are not considered
sns.heatmap(plot_df, ax=ax, cbar=False, cmap="Blues", annot=True, annot_kws={'fontsize': 12}, fmt=",.0f")

ax.set_ylabel("Intramolecular isopeptide bond - containing domains")
ax.set_xlabel("Non intramolecular isopeptide bond - containing domains")
# Out:
# Text(0.5, 80.5815972222222, 'Non intramolecular isopeptide bond - containing domains')

# %%
duf11_proteins = str_df[(str_df["probability"]>.65)&(str_df["pfamA_id"]=="DUF11")&(str_df["kingdom"]=="Archaea")]["uniprot_acc"].unique()
table_df[table_df["uniprot_acc"].isin(duf11_proteins) & (table_df["pfamA_id"]=="HemolysinCabind")]
# Out:
#        uniprot_acc pfamA_acc         pfamA_id seq_start seq_end  probability
# 871898  A0A522XLB4   PF00353  HemolysinCabind     867.0   900.0          0.0
# 871899  A0A522XLB4   PF00353  HemolysinCabind     874.0   909.0          0.0
# 871900  A0A522XLB4   PF00353  HemolysinCabind     892.0   927.0          0.0
# 871901  A0A522XLB4   PF00353  HemolysinCabind     901.0   936.0          0.0
# 871902  A0A522XLB4   PF00353  HemolysinCabind     928.0   963.0          0.0
# 871903  A0A522XLB4   PF00353  HemolysinCabind     964.0   999.0          0.0
# 871904  A0A522XLB4   PF00353  HemolysinCabind     991.0  1026.0          0.0
# 871905  A0A522XLB4   PF00353  HemolysinCabind    1000.0  1035.0          0.0
# 871906  A0A522XLB4   PF00353  HemolysinCabind    1018.0  1053.0          0.0
# 871907  A0A522XLB4   PF00353  HemolysinCabind    1027.0  1062.0          0.0
# 871908  A0A522XLB4   PF00353  HemolysinCabind    1054.0  1089.0          0.0
# 871842  A0A522XQP9   PF00353  HemolysinCabind     869.0   902.0          0.0
# 871843  A0A522XQP9   PF00353  HemolysinCabind     876.0   910.0          0.0
# 871844  A0A522XQP9   PF00353  HemolysinCabind     894.0   929.0          0.0
# 871845  A0A522XQP9   PF00353  HemolysinCabind     903.0   938.0          0.0
# 871846  A0A522XQP9   PF00353  HemolysinCabind     930.0   965.0          0.0
# 871847  A0A522XQP9   PF00353  HemolysinCabind     948.0   983.0          0.0
# 871848  A0A522XQP9   PF00353  HemolysinCabind     966.0  1001.0          0.0
# 871849  A0A522XQP9   PF00353  HemolysinCabind     975.0  1010.0          0.0
# 871850  A0A522XQP9   PF00353  HemolysinCabind    1002.0  1037.0          0.0
# 871851  A0A522XQP9   PF00353  HemolysinCabind    1011.0  1046.0          0.0
# 871852  A0A522XQP9   PF00353  HemolysinCabind    1047.0  1082.0          0.0
# 871853  A0A522XQP9   PF00353  HemolysinCabind    1056.0  1091.0          0.0
# 871861  A0A7D5R6P8   PF00353  HemolysinCabind     868.0   901.0          0.0
# 871862  A0A7D5R6P8   PF00353  HemolysinCabind     875.0   909.0          0.0
# 871863  A0A7D5R6P8   PF00353  HemolysinCabind     893.0   928.0          0.0
# 871864  A0A7D5R6P8   PF00353  HemolysinCabind     902.0   937.0          0.0
# 871865  A0A7D5R6P8   PF00353  HemolysinCabind     929.0   964.0          0.0
# 871866  A0A7D5R6P8   PF00353  HemolysinCabind     938.0   973.0          0.0
# 871867  A0A7D5R6P8   PF00353  HemolysinCabind     965.0  1000.0          0.0
# 871868  A0A7D5R6P8   PF00353  HemolysinCabind     974.0  1009.0          0.0
# 871869  A0A7D5R6P8   PF00353  HemolysinCabind    1010.0  1045.0          0.0
# 871870  A0A7D5R6P8   PF00353  HemolysinCabind    1019.0  1054.0          0.0
# 871871  A0A7D5R6P8   PF00353  HemolysinCabind    1046.0  1081.0          0.0
# 871872  A0A7D5R6P8   PF00353  HemolysinCabind    1055.0  1090.0          0.0
# 871954  A0A7D5RAQ6   PF00353  HemolysinCabind     370.0   412.0          0.0
# 871955  A0A7D5RAQ6   PF00353  HemolysinCabind     413.0   448.0          0.0
# 871956  A0A7D5RAQ6   PF00353  HemolysinCabind     440.0   475.0          0.0
# 871957  A0A7D5RAQ6   PF00353  HemolysinCabind     476.0   511.0          0.0
# 871958  A0A7D5RAQ6   PF00353  HemolysinCabind     485.0   520.0          0.0
# 871959  A0A7D5RAQ6   PF00353  HemolysinCabind     503.0   538.0          0.0
# 871960  A0A7D5RAQ6   PF00353  HemolysinCabind     512.0   547.0          0.0
# 871961  A0A7D5RAQ6   PF00353  HemolysinCabind     539.0   574.0          0.0

# %%
fig, ax = plt.subplots()

ax.axis("off")
plot_df = df[df["kingdom"].isin(["Bacteria", "Archaea", "Eukaryota"])].copy()
plot_df["Bond"] = "Low confidence"
plot_df.loc[plot_df["probability"]>=.65, "Bond"] = "High confidence"

plot_df = plot_df.sort_values("probability", ascending=False).drop_duplicates("uniprot_acc", keep="first").value_counts("Bond").reset_index()
plot_df["Bond"] = plot_df["Bond"] + " (" + plot_df["count"].astype(str) + ")"
count_dict = dict(zip(plot_df["Bond"], plot_df["count"]))

labels = count_dict.keys()
sizes = list(count_dict.values())

ax.pie(sizes, labels=labels, colors=["Black", "C0"], explode=(.1, .1), startangle=30)
ax.set_title("Isopeptide bond predictions", weight="bold")

plt.savefig("../tmp/pie.png", dpi=400, transparent=True, bbox_inches="tight")

# %%
fig, ax = plt.subplots()

plot_df = df[(df["kingdom"].isin(["Bacteria", "Archaea", "Eukaryota"]))&(df["probability"]>=.65)]\
          .drop_duplicates("uniprot_acc").value_counts("kingdom").reset_index()
plot_df["kingdom"] = plot_df["kingdom"] + " (" + plot_df["count"].astype(str) + ")"
sns.barplot(plot_df, y="count", x="kingdom")

sns.despine(offset=10)
ax.set_xlabel("")
ax.set_ylabel("Proteins")
plt.savefig("../tmp/bar.png", dpi=400, transparent=True, bbox_inches="tight")

# %% [markdown]
# ## Presence of sortase motifs

# %%
import re 
S = re.compile('LP.T[G|A|N|D]')
S2 = re.compile('NP.TG')
S3 = re.compile('LP.GA')
S4 = re.compile('LA.TG')
S5 = re.compile('NPQTN')
S6 = re.compile('IP.TG')

def find_sortase(seq:str):
    """
    
        Find sortase motifs within 50 amino acids from C-ter
    
    """
    sortase = False
    seq = seq[-50:]
    if S.findall(seq):
        sortase = True
    elif S2.findall(seq):
        sortase = True
    elif S3.findall(seq):
        sortase = True
    elif S4.findall(seq):
        sortase = True
    elif S5.findall(seq):
        sortase = True
    elif S6.findall(seq):
        sortase = True
    
    return sortase

# %%
ib_proteins = str_df[(str_df["probability"]>.65)&(str_df["kingdom"]=="Bacteria")&(~str_df["pfamA_id"].isin(non_isopep))]["uniprot_acc"].unique()

sub_df = seq_df[(seq_df["uniprot_acc"].isin(ib_proteins))].copy()
sub_df["Sortase"] = sub_df["sequence"].apply(find_sortase)

# %%
sub_df.value_counts("Sortase", normalize=True)
# Out:
# Sortase
# False    0.604051
# True     0.395949
# Name: proportion, dtype: float64

# %% [markdown]
# ## Inserted domains

# %%
# Get domains with insertions
cond1 = (str_df["probability"]>.65)
cond2 = (~str_df["taxonomy"].isna())
plot_df = str_df[cond1&cond2].copy()
plot_df["Interbond-length"] = plot_df["r2_bond"] - plot_df["r1_bond"]
sns.histplot(plot_df, x="Interbond-length")
plt.xlim([0,500])
plt.ylim([0,500])
# Out:
# (0.0, 500.0)

# %%
# Select bonds with potential insertion
cond1 = (str_df["probability"]>.65)
cond2 = (~str_df["taxonomy"].isna())
idf = str_df[cond1&cond2].copy()
idf["Interbond-length"] = idf["r2_bond"] - idf["r1_bond"]
idf = pd.merge(idf[idf["Interbond-length"]>200][["uniprot_acc", "r1_bond", "r2_bond"]], strd_df, how="left").query('seq_start>=r1_bond&seq_end<=r2_bond')
idf.value_counts("pfamA_id")
# Out:
# pfamA_id
# VWA               369
# VWA_2             222
# WD40              139
# GBS104-like_Ig     45
# TED                43
# SpaA               36
# Big_8              33
# SdrG_C_C           21
# Big_2              15
# pAdhesive_15       11
# DUF11               9
# PQQ                 6
# Lactonase           3
# Exo_endo_phos2      3
# CBM26               2
# CBM_4_9             2
# Cna_B               2
# P_proprotein        2
# Laminin_G_3         2
# InhA-like_MAM       2
# F5_F8_type_C        1
# FctA                1
# PA14                1
# NIDO                1
# Peptidase_S8        1
# Name: count, dtype: int64

# %%
str_df[(str_df["pfamA_id"]=="SpaA_3")].sort_values("probability")
# Out:
#                                               struct_file uniprot_acc  \
# 4337    /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A291A5D5
# 126287  /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A7K0M5I5
# 351113  /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A4Q6GH45
# 43154   /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A845B862
# 287777  /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A6H2DQP0
# ...                                                   ...         ...
# 241913  /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A852WPJ5
# 52011   /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A1C9U4I8
# 5460    /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A291A2P0
# 311309  /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A514BTT6
# 372487  /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A848UEA0
#
#         probability chain  r1_bond  r_cat  r2_bond r1_bond_name r_cat_name  \
# 4337          0.096     A      268    326      379          LYS        GLU
# 126287        0.187     A      476    520      568          LYS        GLU
# 351113        0.205     A      133    188      239          LYS        GLU
# 43154         0.215     A      250    306      362          LYS        GLU
# 287777        0.219     A      247    303      359          LYS        GLU
# ...             ...   ...      ...    ...      ...          ...        ...
# 241913        0.880     A      461    519      573          LYS        GLU
# 52011         0.885     A      672    717      766          LYS        GLU
# 5460          0.886     A      497    551      596          LYS        GLU
# 311309        0.887     A      298    353      409          LYS        GLU
# 372487        0.909     A      181    234      278          LYS        GLU
#
#        r2_bond_name  bond_type   rmsd  r_asa            template pfamA_acc  \
# 4337            ASN  CnaB-like  0.940  0.036   2y1v_A_41_143_184   PF20674
# 126287          ASN  CnaB-like  0.837  0.033  2xtl_A_355_416_437   PF20674
# 351113          ASN  CnaB-like  0.825  0.017  3b2m_A_179_258_303   PF20674
# 43154           ASN  CnaB-like  0.816  0.023  8f70_A_299_386_437   PF20674
# 287777          ASN  CnaB-like  0.813  0.022  3b2m_A_179_258_303   PF20674
# ...             ...        ...    ...    ...                 ...       ...
# 241913          ASN  CnaB-like  0.378  0.008  3b2m_A_179_258_303   PF20674
# 52011           ASN  CnaB-like  0.373  0.006  3gld_A_179_258_303   PF20674
# 5460            ASN  CnaB-like  0.369  0.017  7f7y_A_246_328_375   PF20674
# 311309          ASN  CnaB-like  0.370  0.005  6bbw_A_163_236_279   PF20674
# 372487          ASN  CnaB-like  0.322  0.067  6bbw_A_163_236_279   PF20674
#
#        pfamA_id clan_acc        clan_id  seq_start  seq_end  \
# 4337     SpaA_3   CL0287  Transthyretin      263.0    381.0
# 126287   SpaA_3   CL0287  Transthyretin      495.0    570.0
# 351113   SpaA_3   CL0287  Transthyretin      128.0    241.0
# 43154    SpaA_3   CL0287  Transthyretin      245.0    364.0
# 287777   SpaA_3   CL0287  Transthyretin      242.0    361.0
# ...         ...      ...            ...        ...      ...
# 241913   SpaA_3   CL0287  Transthyretin      456.0    575.0
# 52011    SpaA_3   CL0287  Transthyretin      686.0    768.0
# 5460     SpaA_3   CL0287  Transthyretin      492.0    598.0
# 311309   SpaA_3   CL0287  Transthyretin      293.0    411.0
# 372487   SpaA_3   CL0287  Transthyretin      188.0    280.0
#
#                                                  taxonomy  \
# 4337    Bacteria; Pseudomonadota; Gammaproteobacteria;...
# 126287           Bacteria; Actinomycetota; Actinomycetes.
# 351113  Bacteria; Pseudomonadota; Gammaproteobacteria;...
# 43154   Bacteria; Pseudomonadota; Alphaproteobacteria;...
# 287777  Bacteria; Pseudomonadota; Alphaproteobacteria;...
# ...                                                   ...
# 241913  Bacteria; Actinomycetota; Actinomycetes; Micro...
# 52011                    Bacteria; environmental samples.
# 5460    Bacteria; Pseudomonadota; Gammaproteobacteria;...
# 311309  Bacteria; Pseudomonadota; Gammaproteobacteria;...
# 372487  Bacteria; Actinomycetota; Acidimicrobiia; Acid...
#
#                                 species   kingdom  is_domain  r1_plddt  \
# 4337                 Lysobacter capsici  Bacteria       True     97.88
# 126287          Actinomycetia bacterium  Bacteria       True     89.44
# 351113       Xanthomonadaceae bacterium  Bacteria       True     93.12
# 43154   Allopontixanthobacter sediminis  Bacteria       True     95.31
# 287777  Parasphingorhabdus halotolerans  Bacteria       True     96.94
# ...                                 ...       ...        ...       ...
# 241913          Pedococcus badiiscoriae  Bacteria       True     97.12
# 52011         uncultured bacterium pAX1  Bacteria       True     89.62
# 5460                 Lysobacter capsici  Bacteria       True     97.81
# 311309            Lysobacter alkalisoli  Bacteria       True     98.25
# 372487                 Ilumatobacter sp  Bacteria       True     98.06
#
#         r2_plddt  r3_plddt  mean_plddt
# 4337       98.56     98.12   98.186667
# 126287     85.75     86.81   87.333333
# 351113     95.06     93.69   93.956667
# 43154      97.56     97.75   96.873333
# 287777     97.44     97.81   97.396667
# ...          ...       ...         ...
# 241913     97.12     93.06   95.766667
# 52011      95.56     86.50   90.560000
# 5460       97.88     97.50   97.730000
# 311309     98.31     98.31   98.290000
# 372487     96.62     97.31   97.330000
#
# [474 rows x 28 columns]

# %%
str_df[(str_df["probability"]>.65)&(str_df["r2_bond_name"]=="ASP")].value_counts("pfamA_id").iloc[:20]
# Out:
# pfamA_id
# SpaA               2740
# GramPos_pilinD1      45
# Ion_trans            10
# AsmA                  8
# GramPos_pilinD3       6
# DUF5979               4
# DUF2334               3
# Peptidase_C13         2
# Glyco_hydro_3         1
# Memo                  1
# Nrap_D2               1
# NB-ARC                1
# Name: count, dtype: int64

# %%
str_df[str_df["pfamA_id"]=="Ion_trans"].sort_values("probability")
# Out:
#                                               struct_file uniprot_acc  \
# 375666  /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A034VZ15
# 236689  /hps/nobackup/agb/research/francesco/tmp/jessA...      A1A713
# 63157   /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A0K8UEH0
# 27333   /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A182K659
# 246630  /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A0J7KFB1
# ...                                                   ...         ...
# 81882   /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A443SN59
# 81885   /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A218UDN0
# 361068  /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A523IXH6
# 189616  /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A2J8T503
# 56266   /hps/nobackup/agb/research/francesco/tmp/jessA...  A0A2B4SAY7
#
#         probability chain  r1_bond  r_cat  r2_bond r1_bond_name r_cat_name  \
# 375666        0.032     A      103     53      105          LYS        GLU
# 236689        0.036     A      123     73      125          LYS        GLU
# 63157         0.037     A      103     53      105          LYS        GLU
# 27333         0.037     A      246    201      248          LYS        GLU
# 246630        0.041     A      265    305      302          LYS        ASP
# ...             ...   ...      ...    ...      ...          ...        ...
# 81882         0.668     A      200    142      168          LYS        GLU
# 81885         0.676     A      193    136      162          LYS        GLU
# 361068        0.680     A      132     74       97          LYS        GLU
# 189616        0.681     A      226    169      195          LYS        GLU
# 56266         0.683     A      335    272      295          LYS        GLU
#
#        r2_bond_name  bond_type   rmsd  r_asa            template pfamA_acc  \
# 375666          ASP  CnaB-like  1.000  0.425   5yu5_A_45_145_181   PF00520
# 236689          ASP  CnaB-like  0.984  0.428      8bdw_A_9_59_91   PF00520
# 63157           ASP  CnaB-like  0.979  0.433      8bdw_A_9_59_91   PF00520
# 27333           ASP  CnaB-like  0.979  0.430      8bdw_A_9_59_91   PF00520
# 246630          ASN  CnaA-like  0.999  0.296  8beg_A_590_636_729   PF00520
# ...             ...        ...    ...    ...                 ...       ...
# 81882           ASP  CnaB-like  0.551  0.011   5z0z_A_45_145_181   PF00520
# 81885           ASP  CnaB-like  0.539  0.041  5hbb_A_184_269_295   PF00520
# 361068          ASP  CnaB-like  0.544  0.011   5z0z_A_45_145_181   PF00520
# 189616          ASP  CnaB-like  0.545  0.004   5z0z_A_45_145_181   PF00520
# 56266           ASP  CnaB-like  0.537  0.031      8bdw_A_9_59_91   PF00520
#
#          pfamA_id clan_acc      clan_id  seq_start  seq_end  \
# 375666  Ion_trans   CL0030  Ion_channel        1.0    187.0
# 236689  Ion_trans   CL0030  Ion_channel        5.0    207.0
# 63157   Ion_trans   CL0030  Ion_channel        1.0    187.0
# 27333   Ion_trans   CL0030  Ion_channel       34.0    330.0
# 246630  Ion_trans   CL0030  Ion_channel      107.0    360.0
# ...           ...      ...          ...        ...      ...
# 81882   Ion_trans   CL0030  Ion_channel      102.0    387.0
# 81885   Ion_trans   CL0030  Ion_channel       86.0    344.0
# 361068  Ion_trans   CL0030  Ion_channel       26.0    244.0
# 189616  Ion_trans   CL0030  Ion_channel      128.0    436.0
# 56266   Ion_trans   CL0030  Ion_channel      219.0    449.0
#
#                                                  taxonomy  \
# 375666  Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hex...
# 236689  Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hex...
# 63157   Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hex...
# 27333   Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hex...
# 246630  Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hex...
# ...                                                   ...
# 81882   Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Che...
# 81885   Eukaryota; Metazoa; Chordata; Craniata; Verteb...
# 361068                 Bacteria; Candidatus Dadabacteria.
# 189616  Eukaryota; Metazoa; Chordata; Craniata; Verteb...
# 56266   Eukaryota; Metazoa; Cnidaria; Anthozoa; Hexaco...
#
#                                                   species    kingdom  \
# 375666  Bactrocera dorsalis (Oriental fruit fly) (Dacu...  Eukaryota
# 236689                Drosophila melanogaster (Fruit fly)  Eukaryota
# 63157   Bactrocera latifrons (Malaysian fruit fly) (Ch...  Eukaryota
# 27333                                  Anopheles christyi  Eukaryota
# 246630                    Lasius niger (Black garden ant)  Eukaryota
# ...                                                   ...        ...
# 81882                            Leptotrombidium deliense  Eukaryota
# 81885        Lonchura striata domestica (Bengalese finch)  Eukaryota
# 361068                             Dadabacteria bacterium   Bacteria
# 189616  Pongo abelii (Sumatran orangutan) (Pongo pygma...  Eukaryota
# 56266    Stylophora pistillata (Smooth cauliflower coral)  Eukaryota
#
#         is_domain  r1_plddt  r2_plddt  r3_plddt  mean_plddt
# 375666       True     87.19     88.31     79.12   84.873333
# 236689       True     88.12     88.88     80.94   85.980000
# 63157        True     86.44     87.69     79.19   84.440000
# 27333        True     86.31     87.88     77.31   83.833333
# 246630       True     87.81     89.06     80.69   85.853333
# ...           ...       ...       ...       ...         ...
# 81882        True     90.69     88.00     84.56   87.750000
# 81885        True     90.62     87.62     85.25   87.830000
# 361068       True     90.94     86.31     78.88   85.376667
# 189616       True     90.44     86.88     85.69   87.670000
# 56266        True     91.94     88.38     77.50   85.940000
#
# [7150 rows x 28 columns]

# %% [markdown]
# ## Pilins
#
# Domains found on pilins were obtained through a quick literature search of pilin-containing domains

# %%
import sys
sys.path.append("../bin")
from pfamenv import PFAM_HOST,PFAM_PASSWORD,PFAM_PORT,PFAM_USER,PFAM_VERSION
from mysql import connector
import numpy as np

def is_domain(row):
    """

        Assign if at least 2/3 residues are in domain
    
    """
    residues = [row["r1_bond"], row["r_cat"], row["r2_bond"]]
    status = False
    c = 0
    for res in residues:
        if res >= row["seq_start"] and res <= row["seq_end"]:
            c += 1
            #status = True
            #break
    if c >= 2:
        status = True
    return status

# %%
# Get pfam info associated with each PDB
columns = ["pdb_id", "pfamA_acc", "pfamA_id", "chain", "pdb_res_start", "pdb_res_end", "seq_start", "seq_end", "clan_acc", "clan_id"]

proteins = pdb_df[(pdb_df["Is bonded"])&(~pdb_df["Interchain"])&(pdb_df["Isopeptide type"]!="Mutant")]["PDB code"].unique()

cnx = connector.connect(user=PFAM_USER,
                        password=PFAM_PASSWORD,
                        port=PFAM_PORT,
                        host=PFAM_HOST)
cursor = cnx.cursor()

proteins_ = ", ".join([f"'{protein}'" for protein in proteins])

# Get domains
cursor.execute(f"SELECT pdb_id,pfamA.pfamA_acc,pfamA.pfamA_id,chain,pdb_res_start,pdb_res_end,seq_start,seq_end,\
                    clan_membership.clan_acc,clan.clan_id \
                 FROM {PFAM_VERSION}.pdb_pfamA_reg, {PFAM_VERSION}.pfamA, \
                     {PFAM_VERSION}.clan_membership, {PFAM_VERSION}.clan \
                 WHERE pdb_id IN ({proteins_}) \
                 AND pfamA.pfamA_acc = clan_membership.pfamA_acc \
                 AND clan.clan_acc=clan_membership.clan_acc \
                 AND pfamA.pfamA_acc = pdb_pfamA_reg.pfamA_acc")
output = cursor.fetchall()
d_df = pd.DataFrame(output, columns = columns)
d_df["pdb_id"] = d_df["pdb_id"].apply(lambda x: x.lower())
data_df = pd.merge(pdb_df, d_df.rename(columns={"pdb_id":"PDB code", "chain":"Chain"}), how="left")\
        .rename(columns={"Position 1\r\n(Bond 1)":"r1_bond", "Position 2\r\n(catalytic)":"r_cat", "Position 3\r\n(Bond 2)":"r2_bond"})

# Check which domains map to isopep bonds
data_df["is_domain"] = data_df.apply(lambda x: is_domain(x), axis=1)
data_df = data_df.sort_values("is_domain", ascending=False) \
        .drop_duplicates(["PDB code", "r1_bond", "r_cat", "r2_bond"], keep="first")
data_df.loc[data_df["is_domain"]==False, "pfamA_acc"] = np.NaN
data_df.loc[data_df["is_domain"]==False, "pfamA_id"] = np.NaN
data_df.loc[data_df["is_domain"]==False, "seq_start"] = np.NaN
data_df.loc[data_df["is_domain"]==False, "seq_end"] = np.NaN
data_df["seq_start"] = data_df["seq_start"].fillna(0).astype(int)
data_df["seq_end"] = data_df["seq_end"].fillna(0).astype(int)
data_df["residues"] = data_df.apply(lambda x: ", ".join([str(_) for _ in [x["r1_bond"], x["r_cat"], x["r2_bond"]]]), axis=1)
data_df["PDB code"] = data_df["PDB code"].apply(lambda x: x.upper())

# %%
# Which domains are associated with pilins

pilins = ["SPy_0128", "Spy0125", "BcpA", "SpaA", "SpaE", "SpaD", "T-18.1", "GG-SpaC", "tee"]
pilin_domains = data_df[data_df["Name"].isin(pilins)]["pfamA_acc"].dropna().unique()
data_df[data_df["Name"].isin(pilins)][["pfamA_acc", "pfamA_id", "Name"]].dropna().drop_duplicates()
# Out:
#     pfamA_acc         pfamA_id      Name
# 176   PF19407          DUF5979   Spy0125
# 103   PF17802             SpaA   Spy0125
# 164   PF17802             SpaA      SpaD
# 165   PF20623       Sgo0707_N2      SpaD
# 145   PF17802             SpaA      BcpA
# 265   PF12892             FctA    T-18.1
# 268   PF19407          DUF5979    T-18.1
# 273   PF16555  GramPos_pilinD1      SpaE
# 276   PF17802             SpaA      SpaE
# 331   PF19407          DUF5979       tee
# 332   PF12892             FctA       tee
# 37    PF12892             FctA  SPy_0128
# 36    PF19407          DUF5979  SPy_0128

# %%
# What do they associate with

kingdom = "Bacteria"

ib_domains = str_df[(str_df["probability"]>.65)&(str_df["kingdom"].isin([kingdom]))&(str_df["pfamA_acc"].isin(pilin_domains))]["pfamA_acc"].unique()
# Consider only proteins with isopep bonds
ib_proteins = str_df[(str_df["probability"]>.65)&(str_df["kingdom"].isin([kingdom]))&(str_df["pfamA_acc"].isin(pilin_domains))]["uniprot_acc"].unique()

strd_df[(strd_df["uniprot_acc"].isin(ib_proteins))&(~strd_df["pfamA_acc"].isin(ib_domains))].value_counts("pfamA_id").iloc[:50]
# Out:
# pfamA_id
# Gram_pos_anchor         3573
# Cna_B                   2292
# GramPos_pilinBB         1875
# TQ                      1773
# Collagen_bind           1631
# Big_8                   1544
# TED                      839
# DUF11                    378
# VWA                      363
# pAdhesive_15             347
# GBS104-like_Ig           342
# TED_2                    243
# VWA_2                    223
# SdrD_B                   215
# GramPos_pilinD3          133
# Flg_new                  122
# SpaA_3                   114
# SpaA_2                   100
# GEVED                     99
# SHIRT                     95
# CshA_NR2                  95
# AgI_II_C2                 84
# Fn_bind                   82
# RCC1                      52
# SLH                       48
# YSIRK_signal              45
# MucBP                     29
# Big_9                     26
# Sgo0707_N1                24
# SdrG_C_C                  24
# Big_2                     23
# Bact_lectin               19
# T6_Ig_like                18
# Sortase                   14
# DUF6923                   13
# Chlam_PMP                 12
# DUF285                    11
# NLPC_P60                  11
# KxYKxGKxW_sig             10
# WxL                       10
# RCC1_2                     9
# QPE                        8
# Surface-like_ins_dom       8
# Big_6                      5
# GBS_Bsp-like               5
# Big_3_5                    5
# IPTL-CTERM                 5
# AC_1                       4
# PKD                        4
# Flg_new_2                  4
# Name: count, dtype: int64

# %%
# How many repeats
fig, ax = plt.subplots()

plot_df = str_df[(str_df["probability"]>.65)&(str_df["pfamA_acc"].isin(pilin_domains))].value_counts("uniprot_acc").reset_index()
sns.histplot(plot_df, x="count", stat="percent", bins=10, label="Pilins", binrange=[0,10], alpha=.5)

plot_df = str_df[(str_df["probability"]>.65)&(~str_df["pfamA_acc"].isin(pilin_domains))&(~str_df["pfamA_acc"].isin(non_isopep))].value_counts("uniprot_acc").reset_index()
sns.histplot(plot_df, x="count", stat="percent", bins=10, label="Non pilins", binrange=[0,10], alpha=.5)

ax.legend()

# %%
# How long

fig, ax = plt.subplots()

prots = str_df[(str_df["probability"]>.65)&(str_df["pfamA_acc"].isin(pilin_domains))]["uniprot_acc"].unique()
plot_df = seq_df[seq_df["uniprot_acc"].isin(prots)]
sns.kdeplot(plot_df, x="seq_len", cut=0, label="Pilins", ax=ax)

prots = str_df[(str_df["probability"]>.65)&(~str_df["pfamA_acc"].isin(pilin_domains))&(~str_df["pfamA_acc"].isin(non_isopep))]["uniprot_acc"].unique()
plot_df = seq_df[seq_df["uniprot_acc"].isin(prots)]
sns.kdeplot(plot_df, x="seq_len", cut=0, label="Non-pilins", ax=ax)


ax.set_xlim([0,1280])
ax.legend()

# %% [markdown]
# ## FAL prediction

# %%
stalk_df = pd.read_csv(STALK_TABLE).rename(columns={"Pfam ID": "pfamA_acc"})
adh_df = pd.read_csv(ADH_TABLE).rename(columns={"Pfam ID": "pfamA_acc"})
fal_df = pd.read_table(FA_PRED)
p_df = pd.read_csv(PATHOGENS)

# %%
s_df = pd.merge(str_df[(str_df["probability"]>.65)&(~str_df["taxonomy"].isna())], 
                fal_df[["ID", "probability_Adh"]].rename(columns={"ID":"uniprot_acc"}))

# Add pathogenic info
s_df["pathogenic"] = 0
s_df.loc[(s_df["species"].str.contains('|'.join(p_df["species"].to_list()))), "pathogenic"] = 1

s_df["who_priority"] = 0
s_df.loc[(s_df["species"].str.contains('|'.join(p_df[(p_df["who_priority"]==1)]["species"].to_list()))), "who_priority"] = 1
# Out:
# /tmp/ipykernel_1222016/2671341230.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   s_df.loc[(s_df["species"].str.contains('|'.join(p_df["species"].to_list()))), "pathogenic"] = 1

# %%
# 77% are predicted to be fibrillar adhesins
fal_df.value_counts("prediction", normalize=True).round(2)
# Out:
# prediction
# 1    0.77
# 0    0.23
# Name: proportion, dtype: float64

# %%
fal_df.value_counts("prediction")
# Out:
# prediction
# 1    25444
# 0     7605
# Name: count, dtype: int64

# %%
# Which IDP domains are not found in FA?

plot_df = s_df[s_df["probability_Adh"]>.8].value_counts(["pfamA_id"]).iloc[:50].reset_index()

fig, ax = plt.subplots(figsize=[10,5])

g=sns.barplot(plot_df, x="pfamA_id", y="count", ax=ax)
ax.tick_params(axis='x', rotation=90)

# %%
# FA in Bacteria/Archaea

plot_df = s_df.value_counts(["kingdom", "FA"]).reset_index()

fig, ax = plt.subplots(figsize=[10,5])

g=sns.barplot(plot_df, x="kingdom", y="count", hue="FA", ax=ax)
ax.tick_params(axis='x', rotation=90)

# %%
# Which domains co-express with FAs?

# Get domains associated with FA and with non FA
ib_proteins_fa = s_df[(s_df["probability_Adh"]>=.8)&(s_df["kingdom"]\
                        .isin(["Bacteria", "Archaea"]))]["uniprot_acc"].unique()
ib_domains = s_df[(s_df["kingdom"].isin(["Bacteria", "Archaea"]))&(~s_df["pfamA_id"].isin(non_isopep))]["pfamA_acc"].unique()

count_df = strd_df[(strd_df["uniprot_acc"].isin(ib_proteins_fa))&(~strd_df["pfamA_acc"].isin(ib_domains))]\
            .value_counts(["pfamA_acc", "pfamA_id"]).reset_index()

adhesin = adh_df["pfamA_acc"].unique()
stalk = stalk_df["pfamA_acc"].unique()
sorting = ["Por_Secre_tail", "CHU_C", "Sortase motif"]
putative_adhesin = ["Big_8", "VWA_2", "FG-GAP_3", "HemolysinCabind", "SprB",
                   "RCC1", "Beta_helix", "RCC1_2", "SBBP", "LTD", "NosD", "FG-GAP_2",
                   "PA", "K319L-like_PKD", "LysM"]

plot_df = count_df.query("count>50").sort_values("count")
plot_df["count"] = plot_df["count"].apply(np.log10)
plot_df["Domain function"] = "Unknown"
# MErge adhesion and putative adhesion
plot_df.loc[plot_df["pfamA_acc"].isin(adhesin), "Domain function"] = "Adhesion, putative adhesion\nor putative ligand binding"
plot_df.loc[plot_df["pfamA_id"].isin(putative_adhesin), "Domain function"] = "Adhesion, putative adhesion\nor putative ligand binding"
plot_df.loc[plot_df["pfamA_acc"].isin(stalk), "Domain function"] = "Stalk"
plot_df.loc[plot_df["pfamA_id"].isin(sorting), "Domain function"] = "Sorting"

fig, ax = plt.subplots(figsize=[10,5])

cmap = sns.color_palette("Paired", 3)
g=sns.barplot(plot_df, y="count", x="pfamA_id", 
              palette={"Sorting":cmap[2], 'Stalk':cmap[0], 'Adhesion, putative adhesion\nor putative ligand binding':cmap[1],
                       'Unknown':"lightgray"}, 
              ax=ax, hue="Domain function",
              hue_order=["Stalk", "Adhesion, putative adhesion\nor putative ligand binding", "Sorting", "Unknown"],
             width=.7)
g.tick_params(axis='x', rotation=90)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
sns.despine(ax=ax, offset=10)
ax.set_xlabel("")
ax.set_title("Isopeptide bond co-localising domains/motifs in non FAs")
ax.set_ylabel("Count")
ax.set_yticklabels([10**eval(i.get_text()) for i in ax.get_yticklabels()])
# Out:
# /tmp/ipykernel_3390231/3407405337.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([10**eval(i.get_text()) for i in ax.get_yticklabels()])
# [Text(0, 0.0, '1.0'),
#  Text(0, 0.5, '3.1622776601683795'),
#  Text(0, 1.0, '10.0'),
#  Text(0, 1.5, '31.622776601683793'),
#  Text(0, 2.0, '100.0'),
#  Text(0, 2.5, '316.22776601683796'),
#  Text(0, 3.0, '1000.0'),
#  Text(0, 3.5, '3162.2776601683795'),
#  Text(0, 4.0, '10000.0'),
#  Text(0, 4.5, '31622.776601683792')]

# %%
# Which domains co-express with non-FAs?

# Get domains associated with FA and with non FA
ib_proteins_non_fa = s_df[(s_df["probability_Adh"]<.8)&(s_df["kingdom"].isin(["Bacteria", "Archaea"]))]["uniprot_acc"].unique()
ib_domains = s_df[(s_df["kingdom"].isin(["Bacteria", "Archaea"]))&(~s_df["pfamA_id"].isin(non_isopep))]["pfamA_acc"].unique()

count_df = strd_df[(strd_df["uniprot_acc"].isin(ib_proteins_non_fa))&(~strd_df["pfamA_acc"].isin(ib_domains))]\
            .value_counts(["pfamA_acc", "pfamA_id"]).reset_index()

adhesin = adh_df["pfamA_acc"].unique()
stalk = stalk_df["pfamA_acc"].unique()
sorting = ["Por_Secre_tail", "CHU_C", "Sortase motif"]
putative_adhesin = ["Big_8", "VWA_2", "FG-GAP_3", "HemolysinCabind", "SprB",
                   "RCC1", "Beta_helix", "RCC1_2", "SBBP", "LTD", "NosD", "FG-GAP_2",
                   "PA", "K319L-like_PKD", "LysM"]

plot_df = count_df.query("count>50").sort_values("count")
plot_df["count"] = plot_df["count"].apply(np.log10)
plot_df["Domain function"] = "Unknown"
# MErge adhesion and putative adhesion
plot_df.loc[plot_df["pfamA_acc"].isin(adhesin), "Domain function"] = "Adhesion, putative adhesion\nor putative ligand binding"
plot_df.loc[plot_df["pfamA_id"].isin(putative_adhesin), "Domain function"] = "Adhesion, putative adhesion\nor putative ligand binding"
plot_df.loc[plot_df["pfamA_acc"].isin(stalk), "Domain function"] = "Stalk"
plot_df.loc[plot_df["pfamA_id"].isin(sorting), "Domain function"] = "Sorting"

fig, ax = plt.subplots(figsize=[10,5])

cmap = sns.color_palette("Paired", 3)
g=sns.barplot(plot_df, y="count", x="pfamA_id", 
              palette={"Sorting":cmap[2], 'Stalk':cmap[0], 'Adhesion, putative adhesion\nor putative ligand binding':cmap[1],
                       'Unknown':"lightgray"}, 
              ax=ax, hue="Domain function",
              hue_order=["Stalk", "Adhesion, putative adhesion\nor putative ligand binding", "Sorting", "Unknown"],
             width=.7)
g.tick_params(axis='x', rotation=90)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
sns.despine(ax=ax, offset=10)
ax.set_xlabel("")
ax.set_title("Isopeptide bond co-localising domains/motifs in non FAs")
ax.set_ylabel("Count")
ax.set_yticklabels([10**eval(i.get_text()) for i in ax.get_yticklabels()])
# Out:
# /tmp/ipykernel_3390231/2209426814.py:42: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([10**eval(i.get_text()) for i in ax.get_yticklabels()])
# [Text(0, 0.0, '1.0'),
#  Text(0, 0.5, '3.1622776601683795'),
#  Text(0, 1.0, '10.0'),
#  Text(0, 1.5, '31.622776601683793'),
#  Text(0, 2.0, '100.0'),
#  Text(0, 2.5, '316.22776601683796'),
#  Text(0, 3.0, '1000.0'),
#  Text(0, 3.5, '3162.2776601683795'),
#  Text(0, 4.0, '10000.0')]

# %%
# How many FA-IBD proteins do pathogens have:

s_df[(s_df["pathogenic"]==1)].drop_duplicates("uniprot_acc").value_counts("FA")
# Out:
# FA
# 1    2794
# 0     230
# Name: count, dtype: int64

# %%
s_df[(s_df["who_priority"]==1)].drop_duplicates("uniprot_acc").value_counts("FA")
# Out:
# FA
# 1    77
# 0    17
# Name: count, dtype: int64

# %%
s_df.to_csv("../tmp/20250212_ib_fa_patho.csv", index=False)

# %%
str_df[(str_df["pfamA_id"].isin(
    ["DUF7619", "DUF7601", "DUF7604", "DUF7617", 
     "SpaA_4", "DUF7507", "DUF7926", "DUF7927", 
     "DUF7929", "DUF7925"]))][["pfamA_id", "pfamA_acc"]].drop_duplicates()
# Out:
#        pfamA_id pfamA_acc
# 333645  DUF7507   PF24346
# 334082  DUF7617   PF24593
# 334397  DUF7619   PF24595
# 334729   SpaA_4   PF24514
# 335135  DUF7925   PF25546
# 335730  DUF7927   PF25549
# 338331  DUF7604   PF24558
# 338355  DUF7601   PF24547
# 338845  DUF7929   PF25551
# 342849  DUF7926   PF25548

# %%
fal_df[fal_df["probability_Adh"]>=.9]
# Out:
#                ID  length  treks_07  Any_anchor  Stalks  Any_adh  \
# 26     A0A022N5J7    1148       0.0         1.0     3.0      1.0
# 32     A0A023UE45    1220       0.0         1.0     4.0      0.0
# 42     A0A059MXG1    1075       0.0         1.0     5.0      0.0
# 47     A0A059N0V2     628       0.0         1.0     2.0      1.0
# 48     A0A059N1M2     627       0.0         1.0     2.0      0.0
# ...           ...     ...       ...         ...     ...      ...
# 33027      X8ISV1    1006       0.0         1.0     4.0      1.0
# 33028      X8IWC7    1239       0.0         0.0     3.0      1.0
# 33030      X8JAJ5    1005       1.0         0.0     3.0      1.0
# 33038      X8KAJ8    1141       1.0         1.0     6.0      0.0
# 33042      X8KFF9     738       0.0         1.0     7.0      0.0
#
#        frac_disordered  Hydro_portion  Charge_portion  rel_entropy  ...  \
# 26               23.43           0.35            0.25         0.24  ...
# 32               36.64           0.35            0.21         0.29  ...
# 42               14.98           0.38            0.26         0.29  ...
# 47               17.83           0.36            0.22         0.32  ...
# 48               21.69           0.39            0.23         0.35  ...
# ...                ...            ...             ...          ...  ...
# 33027            25.94           0.38            0.23         0.29  ...
# 33028            31.40           0.36            0.24         0.29  ...
# 33030            23.68           0.36            0.28         0.33  ...
# 33038            16.91           0.38            0.24         0.42  ...
# 33042            29.27           0.34            0.27         0.41  ...
#
#            A      V     I     L     M     F     Y     W  prediction  \
# 26      4.88   6.53  6.18  7.67  0.96  3.75  4.01  1.13           1
# 32      6.80   7.30  6.07  5.25  0.90  3.93  4.10  0.16           1
# 42      7.63   7.63  6.05  6.79  1.21  4.09  3.26  1.02           1
# 47      4.46   7.48  6.21  8.28  0.80  4.30  4.30  0.64           1
# 48      8.45   9.73  4.31  6.70  0.96  3.35  4.78  0.48           1
# ...      ...    ...   ...   ...   ...   ...   ...   ...         ...
# 33027   7.55  11.23  3.38  6.66  1.19  4.08  2.88  0.60           1
# 33028   8.72   8.39  3.47  5.89  1.37  2.82  3.87  1.05           1
# 33030   7.16   8.96  6.07  3.98  1.09  2.99  4.68  0.70           1
# 33038  10.43   9.20  3.86  5.61  0.53  3.68  3.94  0.44           1
# 33042   7.72   9.08  4.07  4.47  0.54  1.76  4.47  1.63           1
#
#        probability_Adh
# 26                1.00
# 32                0.94
# 42                0.94
# 47                1.00
# 48                0.90
# ...                ...
# 33027             1.00
# 33028             1.00
# 33030             1.00
# 33038             0.96
# 33042             0.92
#
# [4638 rows x 32 columns]

# %%
4638/len(fal_df)
# Out:
# 0.1403370752518987

# %% [markdown]
# ## Phyla tree
#
# Not really working since the distance is constant

# %%
import os
from ete3 import Tree
from ete3 import TreeStyle
from ete3 import BarChartFace
from ete3 import NCBITaxa
from Bio import Entrez

# Necessary for ete3 fig generation
os.environ['QT_QPA_PLATFORM']='offscreen'

# %%
df["phylum"] = df["taxonomy"].apply(lambda x: x.split(";")[1].replace(".", "").strip() if len(str(x).split(";")) >= 2 else np.NaN)

# %%
idb_phyla = df[(df["probability"]>.65)&(df["kingdom"].isin(["Bacteria", "Archaea"]))]["phylum"].unique()
idb_phyla = [p for p in idb_phyla if "andidat" not in str(p)]

# %%
# Set your email; NCBI requires this for identification
Entrez.email = "fcosta@ebi.ac.uk"

phyla = idb_phyla

def get_taxid(phyla_name):
    handle = Entrez.esearch(db="taxonomy", term=phyla_name)
    record = Entrez.read(handle)
    handle.close()
    if record["IdList"]:
        return record["IdList"][0]
    else:
        print(f"TaxID not found for {phyla_name}")
        return None

taxids = {phyla: get_taxid(phyla) for phyla in phyla}
rev_taxids = {value:key for key,value in taxids.items()}
# Out:
# TaxID not found for nan
# TaxID not found for Nitrospinae/Tectomicrobia group
# TaxID not found for Bacteria division CPR2
# TaxID not found for Bacteria division KSB1
# TaxID not found for Bacteria division CPR3
# TaxID not found for Bacteria division Kazan-3B-28
# TaxID not found for Bacteria division WOR-3

# %%
ncbi = NCBITaxa()

# Ensure your local NCBI taxonomy database is up-to-date
ncbi.update_taxonomy_database()

# Filter out phyla without TaxIDs
valid_taxids = [int(taxid) for taxid in taxids.values() if taxid]

# Get the phylogenetic tree for the given TaxIDs
tree = ncbi.get_topology(valid_taxids)

# Update leaf nodes
for leaf in tree:
    leaf.name = rev_taxids[leaf.name]
# Out:
# Local taxdump.tar.gz seems up-to-date
# Loading node names...
# 2631460 names loaded.
# 401524 synonyms loaded.
# Loading nodes...
# 2631460 nodes loaded.
# Linking nodes...
# Tree is loaded.
# Updating database: /homes/fcosta/.etetoolkit/taxa.sqlite ...
#  2631000 generating entries...
# Uploading to /homes/fcosta/.etetoolkit/taxa.sqlite
# Inserting synonyms:      30000
# Inserting taxid merges:  60000
# Inserting taxids:       25000
# Inserting taxids:       2630000

# %%
plot_df = df[(df["probability"]>.65)&(df["kingdom"].isin(["Bacteria", "Archaea"]))]\
            .value_counts(["phylum"]).reset_index().set_index("phylum").query('count>100')

# %%
# Ensure the tree is rooted and ordered
tree.set_outgroup(tree.get_leaves()[0])
tree.ladderize()

# Define a function to add bar chart faces to leaves
def add_barchart(leaf, data):
    # Extract the count value for the current leaf
    value = data['count']
    
    # Create a BarChartFace with the count value
    face = BarChartFace([value], width=50, height=20, colors=['red'])
    
    # Reset any previous faces to avoid conflicts and add the bar chart face
    leaf.add_face(face, column=0, position="aligned")

# Apply the function to each leaf
for leaf in tree:
    if leaf.name in plot_df.index:
        add_barchart(leaf, plot_df.loc[leaf.name])

# Create a TreeStyle
ts = TreeStyle()
ts.show_leaf_name = True
ts.scale = 20

# Render the tree
tree.render("../output/figures/phylogenetic_tree_with_barchart.png", tree_style=ts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 27
#      24 ts.scale = 20
#      26 # Render the tree
# ---> 27 tree.render("../output/figures/phylogenetic_tree_with_barchart.png", tree_style=ts)
#
# File /nfs/research/agb/research/francesco/anaconda3/envs/danalysis2/lib/python3.12/site-packages/ete3/coretype/tree.py:1392, in TreeNode.render(self, file_name, layout, w, h, tree_style, units, dpi)
#    1388     return drawer.get_img(self, w=w, h=h,
#    1389                           layout=layout, tree_style=tree_style,
#    1390                           units=units, dpi=dpi, return_format=file_name)
#    1391 else:
# -> 1392     return drawer.render_tree(self, file_name, w=w, h=h,
#    1393                             layout=layout, tree_style=tree_style,
#    1394                               units=units, dpi=dpi)
#
# File /nfs/research/agb/research/francesco/anaconda3/envs/danalysis2/lib/python3.12/site-packages/ete3/treeview/drawer.py:104, in render_tree(t, imgName, w, h, layout, tree_style, header, units, dpi)
#     102     n.add_feature("_nid", nid)
#     103 scene, img = init_scene(t, layout, tree_style)
# --> 104 tree_item, n2i, n2f = render(t, img)
#     106 scene.init_values(t, img, n2i, n2f)
#     107 tree_item.setParentItem(scene.master_item)
#
# File /nfs/research/agb/research/francesco/anaconda3/envs/danalysis2/lib/python3.12/site-packages/ete3/treeview/qt4_render.py:268, in render(root_node, img, hide_root)
#     265     if _leaf(n):# or len(n.img_style["_faces"]["aligned"]):
#     266         virtual_leaves += 1
# --> 268     update_node_faces(n, n2f, img)
#     270 rot_step = float(arc_span) / virtual_leaves
#     271 #rot_step = float(arc_span) / len([n for n in root_node.traverse() if _leaf(n)])
#     272
#     273 # Calculate optimal branch length
#
# File /nfs/research/agb/research/francesco/anaconda3/envs/danalysis2/lib/python3.12/site-packages/ete3/treeview/qt4_face_render.py:389, in update_node_faces(node, n2f, img)
#     386     else:
#     387         as_grid = False
# --> 389     faceblock[position] = _FaceGroupItem(all_faces, node, as_grid=as_grid)
#     391 # all temp and fixed faces are now referenced by the faceblock, so
#     392 # we can clear the node temp faces (don't want temp faces to be
#     393 # replicated with copy or dumped with cpickle)
#     394 node._temp_faces = None
#
# File /nfs/research/agb/research/francesco/anaconda3/envs/danalysis2/lib/python3.12/site-packages/ete3/treeview/qt4_face_render.py:101, in _FaceGroupItem.__init__(self, faces, node, as_grid)
#      99 self.h = 0
#     100 # updates the size of this grid
# --> 101 self.update_columns_size()
#
# File /nfs/research/agb/research/francesco/anaconda3/envs/danalysis2/lib/python3.12/site-packages/ete3/treeview/qt4_face_render.py:137, in _FaceGroupItem.update_columns_size(self, norender)
#     135 f.node = self.node
#     136 if f.type == "pixmap" and not norender:
# --> 137     f.update_pixmap()
#     138 elif f.type == "item" and not norender:
#     139     f.update_items()
#
# File /nfs/research/agb/research/francesco/anaconda3/envs/danalysis2/lib/python3.12/site-packages/ete3/treeview/faces.py:467, in ProfileFace.update_pixmap(self)
#     465 def update_pixmap(self):
#     466     if self.style=="lines":
# --> 467         self.draw_line_profile()
#     468     elif self.style=="heatmap":
#     469         self.draw_heatmap_profile()
#
# File /nfs/research/agb/research/francesco/anaconda3/envs/danalysis2/lib/python3.12/site-packages/ete3/treeview/faces.py:728, in ProfileFace.draw_line_profile(self)
#     726 def draw_line_profile(self):
#     727     # Calculate vector
# --> 728     mean_vector = self.node.profile
#     729     deviation_vector = self.node.deviation
#     730     if mean_vector is None:
#
# AttributeError: 'PhyloNode' object has no attribute 'profile'

# %%
df[df["uniprot_acc"]=="T2GLL5"]
# Out:
# Empty DataFrame
# Columns: [struct_file, uniprot_acc, probability, chain, r1_bond, r_cat, r2_bond, r1_bond_name, r_cat_name, r2_bond_name, bond_type, rmsd, r_asa, template, pfamA_acc, pfamA_id, clan_acc, clan_id, seq_start, seq_end, taxonomy, species, kingdom, is_domain, r1_plddt, r2_plddt, r3_plddt, mean_plddt]
# Index: []
#
# [0 rows x 28 columns]
