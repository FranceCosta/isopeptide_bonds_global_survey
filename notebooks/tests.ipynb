# %%
import matplotlib.pyplot as plt

# %%
# Data to plot
labels = ["", ""]
sizes = [4855, 21979]
colors = ["lightgray", "lightblue"]

# Plot
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors, textprops={'fontsize': 12},
       explode=(0,.1), )
#autopct=lambda pct: f"{pct:.1f}% ({int(pct * sum(sizes) / 100):,})"
plt.savefig("../tmp/f.png", dpi=400, bbox_inches="tight")
